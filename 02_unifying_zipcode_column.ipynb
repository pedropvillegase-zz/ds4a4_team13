# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_rows = None

# %% [markdown]
# ### Cleaning ```zipcode``` real_state

# %%
real_estate = pd.read_csv("datasets/real_estate.csv")
real_estate.head()
# Out:
#    type  zipcode      city state     metro    county  size_rank   1996-04  \
# 0  ZHVI    10025  New York    NY  New York  New York          1       NaN
# 1  ZHVI    60657   Chicago    IL   Chicago      Cook          2  146700.0
# 2  ZHVI    60614   Chicago    IL   Chicago      Cook          3  198000.0
# 3  ZHVI    79936   El Paso    TX   El Paso   El Paso          4   70800.0
# 4  ZHVI    60640   Chicago    IL   Chicago      Cook          5  102300.0
#
#     1996-05   1996-06   ...     2016-09  2016-10  2016-11    2016-12  2017-01  \
# 0       NaN       NaN   ...     1137500  1137700  1152700  1156000.0  1140200
# 1  146500.0  146300.0   ...      318200   318100   318800   320200.0   320800
# 2  195500.0  194200.0   ...      401900   406000   414100   417800.0   417400
# 3   71000.0   71000.0   ...      113800   113900   114100   114500.0   114900
# 4  101300.0  100700.0   ...      198800   199200   200100   201500.0   203000
#
#    2017-02  2017-03  2017-04  2017-05  2017-06
# ...

# %%
real_estate['zipcode'] = real_estate['zipcode'].astype('str')

#real_estate[real_estate['len'] < 5]
real_estate['zipcode_clean'] = real_estate['zipcode']
real_estate['zipcode_clean'][real_estate['zipcode_clean'].isin(['nan', '1m', ' '])] = ''

real_estate['zipcode_clean'] = real_estate['zipcode_clean'].apply( lambda x : x.zfill(5))
real_estate['zipcode_clean'] = list(real_estate['zipcode_clean'].str.slice(0,5))

(real_estate[
    ['zipcode', 'zipcode_clean']
][real_estate['zipcode'] != real_estate['zipcode_clean']]
  .drop_duplicates()
 .sort_values(by = 'zipcode'))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       zipcode zipcode_clean
# 5480     1001         01001
# 3942     1002         01002
# 10325    1005         01005
# 6450     1007         01007
# 12995    1008         01008
# 10780    1010         01010
# 12961    1011         01011
# 4224     1013         01013
# 2465     1020         01020
# 11759    1022         01022
# 13035    1026         01026
# 4888     1027         01027
# 6144     1028         01028
# 7318     1030         01030
# 9321     1033         01033
# 12296    1034         01034
# 9606     1035         01035
# 10152    1036         01036
# 11698    1038         01038
# 1591     1040         01040
# 11766    1050         01050
# 12484    1053         01053
# ...

# %% [markdown]
# ### Cleaning ```zipcode``` listings

# %%
listings = pd.read_csv("datasets/listings.csv")
listings.head()
# Out:
#    accommodates                                          amenities  \
# 0           2.0  {"Cable TV","Wireless Internet","Air condition...
# 1           4.0  {TV,Internet,"Wireless Internet","Air conditio...
# 2           4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 3           3.0  {TV,Internet,"Wireless Internet","Air conditio...
# 4           4.0  {Internet,"Wireless Internet","Air conditionin...
#
#    availability_30  bathrooms  bed_type  bedrooms  beds cancellation_policy  \
# 0               24        1.0  Real Bed       1.0   1.0            moderate
# 1               30        1.0  Real Bed       1.0   1.0            flexible
# 2               30        3.0  Real Bed       3.0   3.0              strict
# 3                8        1.0  Real Bed       1.0   1.0              strict
# 4               17        1.0  Real Bed       1.0   1.0            moderate
#
#                city  has_availability   ...     review_scores_checkin  \
# ...

# %%
listings['zipcode'] = listings['zipcode'].astype('str')

#listings[listings['len'] < 5]
listings['zipcode_clean'] = listings['zipcode']
listings['zipcode_clean'][listings['zipcode_clean'].isin(['nan', '1m', ' '])] = ''

listings['zipcode_clean'] = listings['zipcode_clean'].apply( lambda x : x.zfill(5))
listings['zipcode_clean'] = list(listings['zipcode_clean'].str.slice(0,5))

(listings[
    ['zipcode', 'zipcode_clean']
][listings['zipcode'] != listings['zipcode_clean']]
  .drop_duplicates()
 .sort_values(by = 'zipcode'))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#             zipcode zipcode_clean
# 52757                       00000
# 50499   02108 02111         02108
# 51843    02134-1704         02134
# 22179       10000.0         10000
# 17351       10001.0         10001
# 25277    10002-2289         10002
# 18967       10002.0         10002
# 13779    10003-8623         10003
# 17318       10003.0         10003
# 17355       10009.0         10009
# 17317       10010.0         10010
# 17426       10011.0         10011
# 18854       10012.0         10012
# 19170       10013.0         10013
# 18914       10014.0         10014
# 17434       10016.0         10016
# 24469       10017.0         10017
# 21806       10018.0         10018
# ...

# %% [markdown]
# ### Cleaning ```zipcode``` demographics

# %%
demographics = pd.read_csv("datasets/demographics.csv")
demographics.head()
# Out:
#    zipcode  5_years_or_less  5-9_years  10-14_years  15-19_years  20-24_years  \
# 0      601            17982       1006         1080         1342         1352
# 1      602            40260       2006         2440         2421         2953
# 2      603            52408       2664         3177         3351         3685
# 3      606             6331        347          331          461          474
# 4      610            28328       1438         1490         2044         2122
#
#    25-34_years  35-44_years  45-54_years  55-59_years          ...           \
# 0         1321         2253         2149         2434          ...
# 1         2865         5124         5139         5947          ...
# 2         3585         6473         6775         6678          ...
# 3          469          707          933          776          ...
# 4         1985         3358         3778         3858          ...
#
#    $10,000-$14,999  $15,000-$24,999  $25,000-$34,999  $35,000-$49,999  \
# ...

# %%
demographics['zipcode'] = demographics['zipcode'].astype('str')

#demographics[demographics['len'] < 5]
demographics['zipcode_clean'] = demographics['zipcode']
demographics['zipcode_clean'][demographics['zipcode_clean'].isin(['nan', '1m', ' '])] = ''

demographics['zipcode_clean'] = demographics['zipcode_clean'].apply( lambda x : x.zfill(5))
demographics['zipcode_clean'] = list(demographics['zipcode_clean'].str.slice(0,5))

(demographics[
    ['zipcode', 'zipcode_clean']
][demographics['zipcode'] != demographics['zipcode_clean']]
  .drop_duplicates()
 .sort_values(by = 'zipcode'))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      zipcode zipcode_clean
# 131     1001         01001
# 132     1002         01002
# 133     1003         01003
# 134     1005         01005
# 135     1007         01007
# 136     1008         01008
# 137     1009         01009
# 138     1010         01010
# 139     1011         01011
# 140     1012         01012
# 141     1013         01013
# 142     1020         01020
# 143     1022         01022
# 144     1026         01026
# 145     1027         01027
# 146     1028         01028
# 147     1029         01029
# 148     1030         01030
# 149     1031         01031
# 150     1032         01032
# 151     1033         01033
# 152     1034         01034
# 153     1035         01035
# ...

# %% [markdown]
# ### ```Zipcode``` joins listings and demographics

# %%
print("listings shape: " +  str(listings.shape))
print("demographics shape: " +  str(demographics.shape))
print("left join between listings and demographics:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(demographics['zipcode_clean']),
     how = 'left',
     on = 'zipcode_clean' ).shape)
)
print("inner join between listings and demographics:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(demographics['zipcode_clean']),
     how = 'inner',
     on = 'zipcode_clean' ).shape)
)

print("right join between listings and demographics:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(demographics['zipcode_clean']),
     how = 'right',
     on = 'zipcode_clean' ).shape)
)
# Out:
# listings shape: (59824, 30)
# demographics shape: (33120, 27)
# left join between listings and demographics:(59824, 1)
# inner join between listings and demographics:(58254, 1)
# right join between listings and demographics:(91017, 1)

# %% [markdown]
# ### ```Zipcode``` joins listings and real_estate

# %%
print("listings shape: " +  str(listings.shape))
print("real_estate shape: " +  str(real_estate.shape))
print("left join between listings and real_estate:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(real_estate['zipcode_clean']),
     how = 'left',
     on = 'zipcode_clean' ).shape)
)
print("inner join between listings and real_estate:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(real_estate['zipcode_clean']),
     how = 'inner',
     on = 'zipcode_clean' ).shape)
)

print("right join between listings and real_estate:" +
    str(pd.DataFrame(
    listings['zipcode_clean'])
 .merge(
     pd.DataFrame(real_estate['zipcode_clean']),
     how = 'right',
     on = 'zipcode_clean' ).shape)
)
# Out:
# listings shape: (59824, 30)
# real_estate shape: (29111, 263)
# left join between listings and real_estate:(99095, 1)
# inner join between listings and real_estate:(97188, 1)
# right join between listings and real_estate:(125694, 1)

# %% [markdown]
# there are ```zipcodes``` duplicated in real_state as in listings, we need a unique ```zipcode``` per row in real_estate

# %%
pd.options.display.max_rows = 20
